# %%
import matplotlib.pyplot as plt
import numpy as np
from models.model_utils import fetch_data
import torch

# %%
loaders = fetch_data(["../data/bp_m_200_64_256.npz"], shuffle=True)
# Out:
# setting up data

# %%
counter = 0
total = 0

for loader in loaders:
    for i, data in enumerate(loader):
        inputs, labels = data[0], data[1]
        input, label = inputs.squeeze(), labels.squeeze()
        plt.imshow(input[3,:,:])
        plt.show()
        break
        # if torch.count_nonzero(input[0,:,:]) == 4096:

            # fig1 = plt.figure(figsize=(10,5))
            #
            # ax1 = fig1.add_subplot(1,2,1)
            # pos1 = ax1.imshow(input[0,:,:],extent=(-1,1,-1,1))
            # ax2 = fig1.add_subplot(1,2,2)
            # pos2 = ax2.imshow(label[0,:,:],extent=(-1,1,-1,1))

        #     counter += 1
        # total += 1

'''

        if torch.count_nonzero(input[3,:,:]) and not torch.count_nonzero(input[1,:,:]) and not torch.count_nonzero(input[2,:,:]) and not torch.count_nonzero(input[0,:,:]):
            counter += 1
            plt.imshow(label[0,:,:])
            plt.show()
        total += 1
            #print(i)

'''

#counter / total

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.load("../data/crops_bp_m_200_256.npz")

# %%
plt.imshow(a["wavespeedlist"][120])
